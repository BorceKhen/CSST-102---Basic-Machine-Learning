# %%
#medical_rule_based_system_borce

age = int(input("Enter your age: "))
#Adult Range dito
if age >= 18:
  print("You are an Adult.")

  temperature = float(input("Enter your body temperature in Celsius: "))

  if temperature >= 38.1:
    print("Diagnosis: High fever")
    print("You need immediate medical attention.")
    go_to_er = input("Do you want to go to the ER(Emergency Room) now? (yes/no): ")
    if go_to_er.lower() == "yes":
        print("Proceed to the ER. A nurse will assist you shortly.")
    else:
        print("Please do monitor your symptoms closely and call a doctor if it worsens.")

  elif 37.1 <= temperature < 38.0:
    print("Diagnosis: Mild fever")
    print("You may be experiencing a viral infection and some discomfort.")
    take_med = input("Do you want to take paracetamol? (yes/no): ")
    if take_med.lower() == "yes":
        print("Take 500mg every 4–6 hours as needed.")
    else:
        print("Make sure to rest and stay hydrated.")

  elif 36.0 <= temperature < 37.0:
    print("Diagnosis: Normal temperature")
    print("You're in good health!")

  else:
    print("Diagnosis: Below normal temperature")
    print("You might be experiencing hypothermia or poor circulation.")
    warm_up = input("Do you want to warm up with a blanket or hot drink? (yes/no): ")
    if warm_up.lower() == "yes":
        print("Good choice. Let’s raise your body temperature gradually.")
    else:
        print("Please stay alert. Seek help if you feel dizzy or weak.")
#Child Range dito
else:
  print("You are a Minor.")
  temperature = float(input("Enter your body temperature in Celsius: "))

  if temperature >= 38.5:
    print("Diagnosis: High fever")
    print("You need immediate medical attention.")
    go_to_er = input("Do you want to go to the ER(Emergency Room) now? (yes/no): ")
    if go_to_er.lower() == "yes":
        print("Proceed to the ER. A nurse will assist you shortly.")
    else:
        print("Please do monitor your symptoms closely and call a doctor if it worsens.")

  elif 37.5 <= temperature < 38.4:
    print("Diagnosis: Mild fever")
    print("You may be experiencing a viral infection and some discomfort.")
    take_med = input("Do you want to take paracetamol? (yes/no): ")
    if take_med.lower() == "yes":
        print("Take 500mg every 4–6 hours as needed.")
    else:
        print("Make sure to rest and stay hydrated.")

  elif 36.5 <= temperature < 37.5:
    print("Diagnosis: Normal temperature")
    print("You're in good health!")

  else:
    print("Diagnosis: Below normal temperature")
    print("You might be experiencing hypothermia or poor circulation.")
    warm_up = input("Do you want to warm up with a blanket or hot drink? (yes/no): ")
    if warm_up.lower() == "yes":
        print("Good choice. Let’s raise your body temperature gradually and stay near to your Parent/Guardian.")
    else:
        print("Please stay alert and seek help to your Parent/Guardian.")
# Out:
# Enter your age: 18
# You are an Adult.
# Enter your body temperature in Celsius: 35
# Diagnosis: Below normal temperature
# You might be experiencing hypothermia or poor circulation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2803093383.py in <cell line: 0>()
#      37     print("Diagnosis: Below normal temperature")
#      38     print("You might be experiencing hypothermia or poor circulation.")
# ---> 39     warm_up = input("Do you want to warm up with a blanket or hot drink? (yes/no): ")
#      40     if warm_up.lower() == "yes":
#      41         print("Good choice. Let’s raise your body temperature gradually.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# ...
